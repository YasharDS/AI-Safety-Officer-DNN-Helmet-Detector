# %%
# !pip install opencv-python
# !pip install cmake
# !pip install dlib
# from dlib import face_recognition
# !pip install face_recognition
# Out:
# Requirement already satisfied: opencv-python in c:\programdata\anaconda3\lib\site-packages
# Requirement already satisfied: numpy>=1.13.3 in c:\programdata\anaconda3\lib\site-packages (from opencv-python)
# You are using pip version 9.0.1, however version 21.3.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# Requirement already satisfied: cmake in c:\programdata\anaconda3\lib\site-packages
# You are using pip version 9.0.1, however version 21.3.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# Requirement already satisfied: dlib in c:\programdata\anaconda3\lib\site-packages
# You are using pip version 9.0.1, however version 21.3.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# Requirement already satisfied: face_recognition in c:\programdata\anaconda3\lib\site-packages
# Requirement already satisfied: Click>=6.0 in c:\programdata\anaconda3\lib\site-packages (from face_recognition)
# Requirement already satisfied: face-recognition-models>=0.3.0 in c:\programdata\anaconda3\lib\site-packages (from face_recognition)
# Requirement already satisfied: dlib>=19.7 in c:\programdata\anaconda3\lib\site-packages (from face_recognition)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from face_recognition)
# Requirement already satisfied: Pillow in c:\programdata\anaconda3\lib\site-packages (from face_recognition)
# You are using pip version 9.0.1, however version 21.3.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import cv2
import os
# from mask import create_mask


folder_path = r"C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat"
#dist_path = "/home/preeth/Downloads"

#c = 0
images = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]
for i in range(len(images)):
    print("the path of the image is", images[i])
    #image = cv2.imread(images[i])
    #c = c + 1
    create_mask(images[i])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-f20505da4c5a> in <module>()
#       1 import cv2
#       2 import os
# ----> 3 from mask import create_mask
#       4
#       5
#
# ModuleNotFoundError: No module named 'mask'

# %%
import os
import sys
import random
import argparse
import numpy as np
from PIL import Image, ImageFile
# !pip install face_recognition

__version__ = '0.3.0'

image_path=r'C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\7105_1913-07-11_1960.jpg'
IMAGE_DIR = r'C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\images\yellow_hat'
DEFAULT_IMAGE_PATH = os.path.join(IMAGE_DIR, 'yellow_hat.png')
# BLACK_IMAGE_PATH = os.path.join(IMAGE_DIR, 'black-mask.png')
# BLUE_IMAGE_PATH = os.path.join(IMAGE_DIR, 'blue-mask.png')
# RED_IMAGE_PATH = os.path.join(IMAGE_DIR, 'red-mask.png')


def cli():
    parser = argparse.ArgumentParser(description='Wear a hat  in the given picture.')
    parser.add_argument('pic_path', help='Picture path.')
    parser.add_argument('--show', action='store_true', help='Whether show picture with safety helmet or not.')
    parser.add_argument('--model', default='hog', choices=['hog', 'cnn'], help='Which face detection model to use.')
    group = parser.add_mutually_exclusive_group()
    group.add_argument('--black', action='store_true', help='Wear black mask')
    group.add_argument('--blue', action='store_true', help='Wear blue mask')
    group.add_argument('--red', action='store_true', help='Wear red mask')
    args = parser.parse_args()

    pic_path = args.pic_path
    if not os.path.exists(args.pic_path):
        print(f'Picture {pic_path} not exists.')
        sys.exit(1)

    if args.black:
        mask_path = BLACK_IMAGE_PATH
    elif args.blue:
        mask_path = BLUE_IMAGE_PATH
    elif args.red:
        mask_path = RED_IMAGE_PATH
    else:
        mask_path = DEFAULT_IMAGE_PATH

    FaceMasker(pic_path, mask_path, args.show, args.model).mask()


def create_mask(image_path):
    pic_path = image_path
    mask_path = r'C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\images\yellow_hat.png'
    show = False
    model = "hog"
    FaceMasker(pic_path, mask_path, show, model).mask()



class FaceMasker:
    KEY_FACIAL_FEATURES = ('nose_bridge', 'chin')

    def __init__(self, face_path, mask_path, show=False, model='hog'):
        self.face_path = face_path
        self.mask_path = mask_path
        self.show = show
        self.model = model
        self._face_img: ImageFile = None
        self._mask_img: ImageFile = None

    def mask(self):
        import face_recognition

        face_image_np = face_recognition.load_image_file(self.face_path)
        face_locations = face_recognition.face_locations(face_image_np, model=self.model)
        face_landmarks = face_recognition.face_landmarks(face_image_np, face_locations)
        self._face_img = Image.fromarray(face_image_np)
        self._mask_img = Image.open(self.mask_path)

        found_face = False
        for face_landmark in face_landmarks:
            # check whether facial features meet requirement
            skip = False
            for facial_feature in self.KEY_FACIAL_FEATURES:
                if facial_feature not in face_landmark:
                    skip = True
                    break
            if skip:
                continue

            # mask face
            found_face = True
            self._mask_face(face_landmark)

        if found_face:
            if self.show:
                self._face_img.show()

            # save
            self._save()
        else:
            print('Found no face.')

    def _mask_face(self, face_landmark: dict):
        nose_bridge = face_landmark['nose_bridge']
        nose_point = nose_bridge[len(nose_bridge) * 1 // 4]
        nose_v = np.array(nose_point)

        chin = face_landmark['chin']
        chin_len = len(chin)
        chin_bottom_point = chin[chin_len // 2]
        chin_bottom_v = np.array(chin_bottom_point)
        chin_left_point = chin[chin_len // 8]
        chin_right_point = chin[chin_len * 7 // 8]

        # split mask and resize
        width = self._mask_img.width
        height = self._mask_img.height
        width_ratio = 1.2
        new_height = int(np.linalg.norm(nose_v - chin_bottom_v))

        # left
        mask_left_img = self._mask_img.crop((0, 0, width // 2, height))
        mask_left_width = self.get_distance_from_point_to_line(chin_left_point, nose_point, chin_bottom_point)
        mask_left_width = int(mask_left_width * width_ratio)
        mask_left_img = mask_left_img.resize((mask_left_width, new_height))

        # right
        mask_right_img = self._mask_img.crop((width // 2, 0, width, height))
        mask_right_width = self.get_distance_from_point_to_line(chin_right_point, nose_point, chin_bottom_point)
        mask_right_width = int(mask_right_width * width_ratio)
        mask_right_img = mask_right_img.resize((mask_right_width, new_height))

        # merge mask
        size = (mask_left_img.width + mask_right_img.width, new_height)
        mask_img = Image.new('RGBA', size)
        mask_img.paste(mask_left_img, (0, 0), mask_left_img)
        mask_img.paste(mask_right_img, (mask_left_img.width, 0), mask_right_img)

        # rotate mask
        angle = np.arctan2(chin_bottom_point[1] - nose_point[1], chin_bottom_point[0] - nose_point[0])
        rotated_mask_img = mask_img.rotate(angle, expand=True)

        # calculate mask location
        center_x = (nose_point[0] + chin_bottom_point[0]) // 2
        center_y = (nose_point[1] + chin_bottom_point[1]+20) // 2

        offset = mask_img.width // 2 - mask_left_img.width
        radian = angle * np.pi / 180
        box_x = center_x + int(offset * np.cos(radian)) - rotated_mask_img.width // 2
        box_y = center_y + int(offset * np.sin(radian)) - rotated_mask_img.height // 2

        # add mask
        self._face_img.paste(mask_img, (box_x, box_y), mask_img)

    def _save(self):
        path_splits = os.path.splitext(self.face_path)
        new_face_path = path_splits[0] + '-with-mask' + path_splits[1]
        self._face_img.save(new_face_path)
        print(f'Save to {new_face_path}')

    @staticmethod
    def get_distance_from_point_to_line(point, line_point1, line_point2):
        distance = np.abs((line_point2[1] - line_point1[1]) * point[0] +
                          (line_point1[0] - line_point2[0]) * point[1] +
                          (line_point2[0] - line_point1[0]) * line_point1[1] +
                          (line_point1[1] - line_point2[1]) * line_point1[0]) / \
                   np.sqrt((line_point2[1] - line_point1[1]) * (line_point2[1] - line_point1[1]) +
                           (line_point1[0] - line_point2[0]) * (line_point1[0] - line_point2[0]))
        return int(distance)


if __name__ == '__main__':
    #cli()
 
    create_mask(image_path)
##################################################################################################
import cv2
import os
# from mask import create_mask


folder_path = r"C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\h
jpg
# Save to C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\30052704_1986-10-22_2010-with-mask.jpg
# the path of the image is C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\30069304_1993-02-14_2012.jpg
# Found no face.
# the path of the image is C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\301406_1946-07-19_2004.jpg
# Save to C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\301406_1946-07-19_2004-with-mask.jpg
# the path of the image is C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\30160605_1988-12-30_2015.jpg
# Found no face.
# the path of the image is C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\30169206_1953-03-23_1982.jpg
# Save to C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\30169206_1953-03-23_1982-with-mask.jpg
# the path of the image is C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\3024306_1960-01-06_2014.jpg
# Save to C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\3024306_1960-01-06_2014-with-mask.jpg
# the path of the image is C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\3024705_1942-08-07_2007.jpg
# Save to C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\3024705_1942-08-07_2007-with-mask.jpg
# the path of the image is C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\30284206_1980-06-07_2014.jpg
# Found no face.
# the path of the image is C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\3031905_1950-12-23_2008.jpg
# Found no face.
# the path of the image is C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\3033605_1983-01-12_2006.jpg
# Found no face.
# the path of the image is C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\30353705_1981-09-13_2013.jpg
# Found no face.
# the path of the image is C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\3038705_1971-03-24_2008.jpg
# Save to C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\3038705_1971-03-24_2008-with-mask.jpg
# the path of the image is C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\30401205_1958-02-24_2011.jpg
# Save to C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\30401205_1958-02-24_2011-with-mask.jpg
# the path of the image is C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\3042105_1973-06-09_1970.jpg
# Found no face.
# the path of the image is C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\30440406_1989-06-24_2011.jpg
# Save to C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\30440406_1989-06-24_2011-with-mask.jpg
# the path of the image is C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\30484204_1992-02-04_2011.jpg
# Save to C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\30484204_1992-02-04_2011-with-mask.jpg
# the path of the image is C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\3050405_1942-03-02_1972.jpg
# Save to C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\3050405_1942-03-02_1972-with-mask.jpg
# the path of the image is C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\3055905_1923-05-17_1944.jpg
# Save to C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\3055905_1923-05-17_1944-with-mask.jpg
# the path of the image is C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\30612404_1985-07-17_2011.jpg
# Save to C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\30612404_1985-07-17_2011-with-mask.jpg
# the path of the image is C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\3062404_1948-05-30_2003.jpg
# Save to C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\3062404_1948-05-30_2003-with-mask.jpg
# the path of the image is C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\30669804_1953-08-01_2009.jpg
# Save to C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\30669804_1953-08-01_2009-with-mask.jpg
# the path of the image is C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\30674705_1986-06-30_2010.jpg
# Save to C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\30674705_1986-06-30_2010-with-mask.jpg
# the path of the image is C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\30682405_1991-11-14_2011.jpg
# Save to C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\30682405_1991-11-14_2011-with-mask.jpg
# the path of the image is C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\30713604_1987-02-24_1980.jpg
# Found no face.
# the path of the image is C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\30732106_1985-01-21_1980.jpg
# Found no face.
# the path of the image is C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\30733405_1984-03-21_1980.jpg
# Found no face.
# the path of the image is C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\30750506_1986-01-02_2012.jpg
# Save to C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\30750506_1986-01-02_2012-with-mask.jpg
# the path of the image is C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\30802904_1988-01-28_2015.jpg
# Save to C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\30802904_1988-01-28_2015-with-mask.jpg
# the path of the image is C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\308404_1947-10-09_1965.jpg
# Save to C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\308404_1947-10-09_1965-with-mask.jpg
# the path of the image is C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\308405_1966-11-29_2008.jpg
# Save to C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\308405_1966-11-29_2008-with-mask.jpg
# the path of the image is C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\30862505_1964-05-29_2004.jpg
# Found no face.
# the path of the image is C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\30862805_1992-11-03_2011.jpg
# Save to C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\30862805_1992-11-03_2011-with-mask.jpg
# the path of the image is C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\30865504_1976-09-23_2010.jpg
# Found no face.
# the path of the image is C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\30871106_1961-12-08_2014.jpg
# Save to C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\30871106_1961-12-08_2014-with-mask.jpg
# the path of the image is C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\3094406_1969-02-17_2010.jpg
# Found no face.
# the path of the image is C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\3095504_1930-09-20_2007.jpg
# Save to C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\3095504_1930-09-20_2007-with-mask.jpg
# the path of the image is C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\31006405_1988-01-14_2011.jpg
# Found no face.
# the path of the image is C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\31011404_1991-04-01_2014.jpg
# Save to C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\31011404_1991-04-01_2014-with-mask.jpg
# the path of the image is C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\31020205_1967-02-24_2007.jpg
# Found no face.
# the path of the image is C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\3104806_1947-04-25_2014.jpg
# Save to C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\3104806_1947-04-25_2014-with-mask.jpg
# the path of the image is C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\31053806_1991-03-19_2014.jpg
# Found no face.
# the path of the image is C:\Users\Naya Academy\Desktop\OpenCV Face recognition\aaa\AI training set\hat\3112706_1982-02-22_2009.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-94acd9082d1f> in <module>()
#     188     #image = cv2.imread(images[i])
#     189     #c = c + 1
# --> 190     create_mask(images[i])
#
# <ipython-input-1-94acd9082d1f> in create_mask(image_path)
#      52     show = False
#      53     model = "hog"
# ---> 54     FaceMasker(pic_path, mask_path, show, model).mask()
#      55
#      56
#
# <ipython-input-1-94acd9082d1f> in mask(self)
#      71
#      72         face_image_np = face_recognition.load_image_file(self.face_path)
# ---> 73         face_locations = face_recognition.face_locations(face_image_np, model=self.model)
#      74         face_landmarks = face_recognition.face_landmarks(face_image_np, face_locations)
#      75         self._face_img = Image.fromarray(face_image_np)
#
# C:\ProgramData\Anaconda3\lib\site-packages\face_recognition\api.py in face_locations(img, number_of_times_to_upsample, model)
#     119         return [_trim_css_to_bounds(_rect_to_css(face.rect), img.shape) for face in _raw_face_locations(img, number_of_times_to_upsample, "cnn")]
#     120     else:
# --> 121         return [_trim_css_to_bounds(_rect_to_css(face), img.shape) for face in _raw_face_locations(img, number_of_times_to_upsample, model)]
#     122
#     123
#
# KeyboardInterrupt:
